# %%
# 1. caricare i dati del file in un dataframe Pandas
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
ilfile = pd.read_csv("/content/drive/MyDrive/2010.csv", sep=";") #sep=";"
# Out:
# Mounted at /content/drive

# %%
ilfile[["Title","Genres"]][0:10]
# Out:
#                                   Title  \
# 0                            127 Hours
# 1                          3 Backyards
# 2                                    3
# 3            8: The Mormon Proposition
# 4  A Turtle's Tale: Sammy's Adventures
# 5                  Alice in Wonderland
# 6                  Alice in Wonderland
# 7                      All Good Things
# 8                      Alpha and Omega
# 9                                Amigo
#
#                                       Genres
# 0         Adventure|Biography|Drama|Thriller
# 1                                      Drama
# 2                       Comedy|Drama|Romance
# 3                                Documentary
# 4                 Adventure|Animation|Family
# 5                   Adventure|Family|Fantasy
# 6                   Adventure|Family|Fantasy
# 7       Crime|Drama|Mystery|Romance|Thriller
# 8  Adventure|Animation|Comedy|Family|Romance
# 9                                  Drama|War

# %%
ilfile.iloc[0:10][["Title", "Genres"]]
# Out:
#                                   Title  \
# 0                            127 Hours
# 1                          3 Backyards
# 2                                    3
# 3            8: The Mormon Proposition
# 4  A Turtle's Tale: Sammy's Adventures
# 5                  Alice in Wonderland
# 6                  Alice in Wonderland
# 7                      All Good Things
# 8                      Alpha and Omega
# 9                                Amigo
#
#                                       Genres
# 0         Adventure|Biography|Drama|Thriller
# 1                                      Drama
# 2                       Comedy|Drama|Romance
# 3                                Documentary
# 4                 Adventure|Animation|Family
# 5                   Adventure|Family|Fantasy
# 6                   Adventure|Family|Fantasy
# 7       Crime|Drama|Mystery|Romance|Thriller
# 8  Adventure|Animation|Comedy|Family|Romance
# 9                                  Drama|War

# %%
ilfile[(ilfile["Language"] == "English") & (ilfile["Country"] == "France")]
# Out:
#                                       Title    Year  \
# 4      A Turtle's Tale: Sammy's Adventures   2010.0
# 59                    From Paris with Love   2010.0
# 64                              Green Zone   2010.0
# 139                                 Rubber   2010.0
# 179                       The Ghost Writer   2010.0
# 185                      The Last Exorcism   2010.0
# 262                                Carnage   2011.0
# 266                             Colombiana   2011.0
# 374                           Silent House   2011.0
# 391                             The Artist   2011.0
# 432              Tinker Tailor Soldier Spy   2011.0
# 543                                Lockout   2012.0
# 550                                 Maniac   2012.0
# 558                            On the Road   2012.0
# 588             Silent Hill: Revelation 3D   2012.0
# 604                                Taken 2   2012.0
# 715                             Blood Ties   2013.0
# ...

# %%
ilfile[(ilfile["Genres"].str.contains("Drama")) & (ilfile["Genres"].str.contains("War"))]
# Out:
#                                                 Title    Year  \
# 9                                              Amigo   2010.0
# 16                                   Beneath Hill 60   2010.0
# 28                                         Centurion   2010.0
# 37                                         Dear John   2010.0
# 64                                        Green Zone   2010.0
# 78                                         Incendies   2010.0
# 142                                      Sarah's Key   2010.0
# 230                                             1911   2011.0
# 232                                    5 Days of War   2011.0
# 268                                       Coriolanus   2011.0
# 284                                       Fort McCoy   2011.0
# 308                   In the Land of Blood and Honey   2011.0
# 402                               The Flowers of War   2011.0
# 430                                 There Be Dragons   2011.0
# ...

# %%
# 6. visualizzare i film fantasy e i thriller
ilfile[(ilfile["Genres"].str.contains("Fantasy")) | (ilfile["Genres"].str.contains("Thriller"))]
# Out:
#                                      Title    Year  \
# 0                               127 Hours   2010.0
# 5                     Alice in Wonderland   2010.0
# 6                     Alice in Wonderland   2010.0
# 7                         All Good Things   2010.0
# 17               Beyond the Black Rainbow   2010.0
# ...                                    ...     ...
# 1591               The Secret                  NaN
# 1594                  Trapped                  NaN
# 1595                  Twisted                  NaN
# 1601               Wolf Creek                  NaN
# 1603  Yu-Gi-Oh! Duel Monsters                  NaN
#
#                                          Genres   Language    Country  \
# 0            Adventure|Biography|Drama|Thriller    English        USA
# 5                      Adventure|Family|Fantasy    English        USA
# 6                      Adventure|Family|Fantasy    English        USA
# ...

# %%
# 9. visualizzare i titoli dei film di cui non si conosce il budget
ilfile[ilfile["Budget"].isna()]["Title"]

# %%
# 10. visualizzare i titoli dei film e il relativo regista. Ordinare a partire dal film che ha il budget più alto

ilfile.sort_values(by=["Budget"], ascending=False)
ilfile[["Title", "Director"]]

# %%
# 11. visualizzare i titoli dei film che hanno incassato più di quanto è stato speso per realizzarli
# Budget;Gross Earnings
ilfile[ilfile["Gross Earnings"] > ilfile["Budget"]]["Title"]
# Out:
# 0                      127 Hours
# 5            Alice in Wonderland
# 6            Alice in Wonderland
# 8                Alpha and Omega
# 15                     Beginners
#                   ...
# 1477             The Jungle Book
# 1483           The Perfect Match
# 1484    The Purge: Election Year
# 1485     The Secret Life of Pets
# 1486                The Shallows
# Name: Title, Length: 548, dtype: object
